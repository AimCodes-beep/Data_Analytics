# %% [markdown]
# #### Check Duplicate Records

# %% [markdown]
# #### Drop Duplicate Records

# %% [markdown]
# #### Check missing or null values

# %% [markdown]
# #### Drop missing or null values

# %% [markdown]
# #### Show top 10 average MSRP (Price) per car brand (rounded figure)?

# %% [markdown]
# #### Show the average MSRP (price) per years (rounded figure)?

# %% [markdown]
# #### Show average Engine HP (power) rounded figure and MPG (efficiency) rounded figure per year?
#
# Hint: Average of (city mpg + highway MPG)

# %% [markdown]
# #### What percentage of cars are Compact, Midsize, or Large?

# %% [markdown]
# #### Which vehicle styles are the most sold (most common) in the dataset?

# %% [markdown]
# #### Which car brands have the most vehicles priced at $40,000 or more and with a popularity score of at least 1000?

# %% [markdown]
# #### Check if there are outliers in Engine HP show boxplot

# %% [markdown]
# #### Check if there are outliers in Engine Cylinder show boxplot

# %% [markdown]
# #### Find upper bound, lower bound, number of outliers in Engine HP

# %% [markdown]
# #### Fill missing values in Number of Doors column with median value then check if values are filled

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("cars.csv")

# %%
df.shape
# Out:
# (11914, 16)

# %% [markdown]
# QUESTION NO 1 CHECKING DUPLICATES RECORDS

# %%
dup=df.duplicated()
dup
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11199, dtype: bool

# %%
df[dup].shape
# Out:
# C:\Users\tmrwi\AppData\Local\Temp\ipykernel_28288\2793828973.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[dup].shape
# (0, 16)

# %% [markdown]
# QUESTION NO 2 DROPPING DUPLICATES VALUES

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# MISSING VALUES AND NULL VALUES

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# QUESTION NO 4

# %%
df.groupby('Model')['MSRP'].mean()
# Out:
# Model
# 1 Series      38276.666667
# 1 Series M    46135.000000
# 100            2000.000000
# 124 Spider    26895.000000
# 190-Class      2000.000000
#                   ...
# iM            18830.000000
# iQ            16168.750000
# tC            21546.428571
# xA            12996.666667
# xD            16683.000000
# Name: MSRP, Length: 713, dtype: float64

# %% [markdown]
# QUESTION NO 5

# %%
df.groupby('Year')['MSRP'].mean()
# Out:
# Year
# 1990     2073.088235
# 1991     2222.909091
# 1992     2192.492958
# 1993     2401.287500
# 1994     2726.070175
# 1995     3269.568627
# 1996     3140.020833
# 1997     4523.543860
# 1998     4433.774194
# 1999     3611.555556
# 2000     3913.186441
# 2001    73832.530303
# 2002    55703.915493
# 2003    68312.340909
# 2004    55907.648352
# 2005    53724.282609
# 2006    39000.882353
# 2007    41172.806306
# 2008    80462.086486
# 2009    59193.114391
# 2010    60151.760369
# 2011    65663.336245
# 2012    71837.336918
# 2013    55201.335740
# 2014    71196.306080
# 2015    52612.756355
# 2016    52579.647783
# 2017    45333.111826
# Name: MSRP, dtype: float64

# %%
df['Vehicle Size'].value_counts()
# Out:
# Vehicle Size
# Midsize    3043
# Compact    2847
# Large      1845
# Name: count, dtype: int64

# %% [markdown]
# QUESTION NO 6

# %%
Midsize_per=(3043/7735)*100
Midsize_per
# Out:
# 39.34065934065934

# %%
Compact=(2847/7735)*100
Compact
# Out:
# 36.806722689075634

# %%
Large=(1845/7735)*100
Large
# Out:
# 23.85261797026503

# %% [markdown]
# QUESTION NO 7

# %%
df['Vehicle Style'].value_counts().sort_values(ascending=False).head(3)
# Out:
# Vehicle Style
# 4dr SUV    2053
# Sedan      1801
# Coupe       922
# Name: count, dtype: int64

# %% [markdown]
# QUESTION NO 8

# %%
df[(df['MSRP']>40000) & (df['Popularity']>=1000)]
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 6      BMW    1 Series  2012  premium unleaded (required)      300.0
# 12     BMW    1 Series  2013  premium unleaded (required)      300.0
# 15     BMW    1 Series  2013  premium unleaded (required)      320.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL  rear wheel drive              2.0
# 1                   6.0            MANUAL  rear wheel drive              2.0
# 6                   6.0            MANUAL  rear wheel drive              2.0
# 12                  6.0            MANUAL  rear wheel drive              2.0
# 15                  6.0            MANUAL  rear wheel drive              2.0
# ...                 ...               ...               ...              ...
# 11901               4.0            MANUAL  rear wheel drive              2.0
# 11902               6.0  AUTOMATED_MANUAL  rear wheel drive              2.0
# 11903               8.0            MANUAL  rear wheel drive              2.0
# 11904               8.0            MANUAL  rear wheel drive              2.0
# 11905               8.0            MANUAL  rear wheel drive              2.0
#
#                              Market Category Vehicle Size Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                         Luxury,Performance      Compact   Convertible
# 6                         Luxury,Performance      Compact   Convertible
# 12                        Luxury,Performance      Compact   Convertible
# 15                   Luxury,High-Performance      Compact   Convertible
# ...                                      ...          ...           ...
# 11901                     Luxury,Performance      Compact   Convertible
# 11902                Luxury,High-Performance      Compact   Convertible
# 11903         Exotic,Luxury,High-Performance      Compact   Convertible
# 11904         Exotic,Luxury,High-Performance      Compact   Convertible
# 11905         Exotic,Luxury,High-Performance      Compact   Convertible
#
#        highway MPG  city mpg  Popularity    MSRP
# 0               26        19        3916   46135
# 1               28        19        3916   40650
# 6               26        17        3916   44100
# 12              28        19        3916   44400
# 15              25        18        3916   48250
# ...            ...       ...         ...     ...
# 11901           34        22        3916   49700
# 11902           24        17        3916   66350
# 11903           19        12        3916  128000
# 11904           19        12        3916  130000
# 11905           19        12        3916  131500
#
# [1583 rows x 16 columns]

# %% [markdown]
# QUESTION NO 9

# %%
sns.boxplot(df['Engine HP'])
# Out:
# <Axes: ylabel='Engine HP'>

# %% [markdown]
# QUESTION NO 10

# %%
q1=df['Engine HP'].quantile(0.25)

# %%
q3=df['Engine HP'].quantile(0.75)

# %%
IQR=q3-q1

# %%
IQR
# Out:
# np.float64(131.0)

# %%
upper_bound=q3+1.5*IQR

# %%
upper_bound
# Out:
# np.float64(521.5)

# %%
lower_bound=q1-1.5*IQR

# %%
lower_bound
# Out:
# np.float64(-2.5)

# %% [markdown]
# QUESTION NO 11

# %%
df['Number of Doors'].isnull().sum() #THERE NO NULL VALUE
# Out:
# np.int64(0)
